# %% [markdown]
# # BAOAB method in Julia

# %%
using LaTeXStrings, Random, Plots, Serialization, StatsBase, Base.Threads, LinearAlgebra, Distributions

function A_step(qp, h)
    q, p = qp
    q = q + h * p
    return [q, p]
end

function B_step(qp, h, force)
    q, p = qp
    F = force
    p = p + h * F
    return [q, p]
end

function O_step(qp, h, A, beta)
    q, p = qp
    alpha = exp(-h * A)
    R = randn(length(q))
    p = alpha * p + sqrt(1 / beta) * sqrt(1 - exp(-2 * h * A)) * R
    return [q, p]
end

function BAOAB_step(q, p, h, A, beta, force)
    qp = copy([q, p])
    qp = B_step(qp, h/2, force)
    qp = A_step(qp, h/2)
    qp = O_step(qp, h, A, beta)
    qp = A_step(qp, h/2)
    qp = B_step(qp, h/2, force)
    q, p = qp
    return q, p
end
# Out:
# BAOAB_step (generic function with 1 method)

# %%
function grad_BLR(data, w, N, n)
    # 2nd model - Large Scale Bayesian Logistic Regression
    dim = size(data, 2) - 1
    x = data[:, 1:dim]
    y = data[:, end]

    sum = zeros(dim)
    for i in 1:n
        a = exp(- y[i] * dot(w, x[i, :]))
        sum = sum .+ ((-y[i] * a  / (1 + a)) .* x[i, :])
    end

    w += sum .* N/n

    return w
end

function run_simulation(q0, p0, Nsteps, h, A, beta, Samples, step_function, grad_U, N, n)
    dim = size(Samples, 2) - 1
    q_traj = zeros(dim,Nsteps)
    p_traj = zeros(dim,Nsteps)
    t_traj = zeros(Nsteps)

    q = copy(q0)
    p = copy(p0)
    t = 0.0

    for i in 1:Nsteps
        idx = randperm(N)[1:n]
        data = Samples[idx,:]
        force = - grad_U(data, q, N, n)
        q, p = step_function(q, p, h, A, beta, force)
        t += h
        
        q_traj[:,i] = q
        p_traj[:,i] = p
        t_traj[i] = t
    end

    return q_traj, p_traj, t_traj
end

function sigmoid(z)
    return 1.0 ./ (1.0 .+ exp.(-z))
end

function predict_data(features, weights)
    # Calculate the linear combination of features and weights
    z = first(features' * weights)
    # Apply the logistic function to get the probability
    probabilities = sigmoid(z)
    # Apply threshold (0.5) for binary classification
    predictions = ifelse.(probabilities .>= 0.5, 1, -1)
    
    return predictions
end

function predict_BLR(q_mean, x_test, y_test)
    t = sum(q_mean)
    if isnan(t) || isinf(t)
        return 0
    end
    predicted_labels = zeros(size(x_test, 1))
    for i in 1:size(x_test, 1)
        predicted_labels[i] = predict_data(x_test[i,:], q_mean)
    end
    accuracy = sum(predicted_labels .== y_test) / length(y_test)
    return accuracy
end

# function RMSE_postmean_BLR(q_mean, x_test, y_test)
#     if isnan(q_mean) || isinf(q_mean)
#         return 0
#     end
# end
# Out:
# predict_BLR (generic function with 1 method)

# %%
function random_projection_matrix(rows, cols)
    matrix = zeros(Int, rows, cols)
    for i in 1:rows
        for j in 1:cols
            rand_num = rand()
            if rand_num <= 1/6
                matrix[i, j] = 1
            elseif rand_num <= 2/6
                matrix[i, j] = -1
            end
        end
    end
    matrix = matrix .* sqrt(3/cols)
    # matrix = rand(Normal(0, 1 / sqrt(rows)), rows, cols)
    return matrix 
end

function save_variable(variable, file_name)
    name = string(file_name, ".jls")
    open(name, "w") do file
        serialize(file, variable)
    end
end
# Out:
# save_variable (generic function with 1 method)

# %%
n_lst = [100, 500, 1000, 3000]
A_lst = 10. .^ range(-1, 2, length=30)
predict_matrix_friction = open(deserialize, "predict_matrix_friction_rep10.jls");

p_ = plot()
title!("predict accuracy of the model")
for i in 1:length(n_lst)
    n = n_lst[i]
    plot!(p_, A_lst, predict_matrix_friction[i,:], label="n=$(n)")
end

xlabel!(p_, "Friction A")
ylabel!(p_, "accuracy")
xaxis!(:log10)
xticks!([0.1, 1, 10, 100])
ylims!(0.93, 0.951)
plot!(legendfontsize=12)

plot(p_, legend=:topright)
display(plot(p_))
# savefig("accuracy_vs_A.pdf")

# %%
n_lst = [100, 500, 1000, 3000]
A_lst = 10. .^ range(-1, 2, length=30)
predict_matrix_friction = zeros(length(n_lst), length(A_lst))
predict_matrix_friction[1,:] = open(deserialize, "predict_matrix_friction_n1.jls"); predict_matrix_friction[2,:] = open(deserialize, "predict_matrix_friction_n2.jls");
predict_matrix_friction[3,:] = open(deserialize, "predict_matrix_friction_n3.jls"); predict_matrix_friction[4,:] = open(deserialize, "predict_matrix_friction_n4.jls");

p_main = plot(
    A_lst, predict_matrix_friction', 
    label=reshape(["n=$(n)" for n in n_lst],1,4), 
    xlabel="Friction A", ylabel="accuracy", 
    xaxis=:log10, xticks=[0.1, 1, 10, 100],  
    legendfontsize=12, legend=:topright
)

p_inset = plot!(
    A_lst, predict_matrix_friction', 
    label="", 
    xaxis=:log10, xticks=[0.1, 1, 10, 100], yticks=[0.94, 0.95], xlims=(0.1, 50), ylims=(0.935, 0.951),
    inset = (1, bbox(0.1, 0.1, 0.6, 0.5, :bottom, :right)), subplot = 2,
    framestyle=:box,
    xlabel="", ylabel="", legend=false
)

display(p_main)
# savefig("accuracy_vs_A_combine.pdf")
# Out:
# "e:\\OneDrive - University of Edinburgh\\MATH11197 Research Skills for CAM\\Group Project\\data\\Langevin Problem 2 - 1\\accuracy_vs_A_combine.pdf"
